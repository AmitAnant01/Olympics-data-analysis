# %% [markdown]
# ![My Image](images/image.png)

# %%
! pip install plotly numpy pandas matplotlib seaborn plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# Dependencies Required for Analysis of the Olympic Dataset

# %%
# IMPORTIN THE DEPENDENCIES
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.cm as cm
import warnings
warnings.filterwarnings('ignore')
import plotly.express as px

# %%
# Loading the Olympic dataset
dataset = pd.read_csv('C:/Users/abhia/OneDrive/Desktop/OlympicData.csv')

# %%
dataset
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
# Checking the shape of the dataset (no. of rows and columns)
dataset.shape
# Out:
# (271116, 15)

# %%
dataset.info
# Out:
# <bound method DataFrame.info of             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# ...

# %%
dataset.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
dataset.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
dataset['ID'].unique()
# Out:
# array([     1,      2,      3, ..., 135569, 135570, 135571],
#       shape=(135571,))

# %%
dataset['Age'].unique()
# Out:
# array([24., 23., 34., 21., 25., 27., 31., 33., 18., 26., 22., 30., 32.,
#        28., 54., 20., 17., 43., 47., 29., 41., 45., 49., 53., 57., nan,
#        19., 38., 35., 16., 37., 15., 42., 46., 40., 36., 14., 39., 48.,
#        52., 44., 55., 50., 71., 63., 51., 58., 13., 60., 75., 65., 56.,
#        64., 68., 84., 12., 72., 59., 61., 70., 74., 62., 67., 69., 73.,
#        66., 11., 76., 88., 96., 80., 10., 81., 77., 97.])

# %%
dataset[((pd.isnull(dataset['Age'])))]
# Out:
#             ID                   Name Sex  Age  Height  Weight         Team  \
# 147         54  Mohamed Jamshid Abadi   M  NaN     NaN     NaN         Iran
# 152         58       Georgi Abadzhiev   M  NaN     NaN     NaN     Bulgaria
# 153         58       Georgi Abadzhiev   M  NaN     NaN     NaN     Bulgaria
# 162         66        Mohamed Abakkar   M  NaN   156.0    48.0        Sudan
# 212        102      Sayed Fahmy Abaza   M  NaN     NaN     NaN        Egypt
# ...        ...                    ...  ..  ...     ...     ...          ...
# 270679  135368      Antonio A. Zucchi   M  NaN     NaN     NaN    Argentina
# 270774  135416              Star Zulu   M  NaN     NaN     NaN       Zambia
# 270793  135426           Max Zumstein   M  NaN     NaN     NaN  Switzerland
# 270804  135434     Edmundo Ziga Erraz   M  NaN   180.0    95.0        Chile
# 270805  135435             Faelo Ziga   M  NaN     NaN     NaN        Chile
#
# ...

# %%
dataset.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %%
dataset.describe(include = ['object'])
# Out:
#                         Name     Sex           Team     NOC        Games  \
# count                 271116  271116         271116  271116       271116
# unique                134732       2           1184     230           51
# top     Robert Tait McKenzie       M  United States     USA  2000 Summer
# freq                      58  196594          17847   18853        13821
#
#         Season    City      Sport                    Event  Medal
# count   271116  271116     271116                   271116  39783
# unique       2      42         66                      765      3
# top     Summer  London  Athletics  Football Men's Football   Gold
# freq    222552   22426      38624                     5733  13372

# %%
dataset.isna().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %%
dataset.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Length: 271116, dtype: bool

# %%
dataset.duplicated().sum()
# Out:
# np.int64(1385)

# %%
dataset.query('Name == "Milkha Singh"')
# Out:
#             ID          Name Sex   Age  Height  Weight   Team  NOC  \
# 221116  111108  Milkha Singh   M  21.0   172.0    66.0  India  IND
# 221117  111108  Milkha Singh   M  21.0   172.0    66.0  India  IND
# 221118  111108  Milkha Singh   M  24.0   172.0    66.0  India  IND
# 221119  111108  Milkha Singh   M  28.0   172.0    66.0  India  IND
#
#               Games  Year  Season       City      Sport  \
# 221116  1956 Summer  1956  Summer  Melbourne  Athletics
# 221117  1956 Summer  1956  Summer  Melbourne  Athletics
# 221118  1960 Summer  1960  Summer       Roma  Athletics
# 221119  1964 Summer  1964  Summer      Tokyo  Athletics
#
#                                        Event Medal
# 221116            Athletics Men's 200 metres   NaN
# 221117            Athletics Men's 400 metres   NaN
# 221118            Athletics Men's 400 metres   NaN
# 221119  Athletics Men's 4 x 400 metres Relay   NaN

# %%
dataset.drop_duplicates(inplace = True)

# %%
dataset.shape
# Out:
# (269731, 15)

# %%
sns.set(style = 'darkgrid')
sns.countplot(x = 'Sex', data = dataset , width = 0.2, palette = 'dark')
plt.title('Distribution by gender')
plt.show()

# %%
sns.displot(x = 'Height', data = dataset ,bins = 10, kde = True, color = 'b')
plt.title('Height Distribution')
plt.show()

# %%
sns.displot(x = 'Age', data = dataset ,bins = 10, kde = True, color = 'r')
plt.title('Height Distribution', color = 'b')
plt.show()

# %%
sns.displot(x = 'Weight', data = dataset ,bins = 10, kde = True, color = 'b')
plt.title('Height Distribution')
plt.show()

# %%
ax = sns.countplot(x='Medal',data=dataset,palette='rainbow')
sns.set(rc={"figure.figsize":(8,4)})
for bars in ax.containers:
    ax.bar_label(bars,label_type='center',color='white')

# %%
plt.figure(figsize=(15,6))
sns.countplot(data=dataset,x='Year',hue='Medal',palette= 'bright')
plt.title("Medal Distribution Over the Years", color= 'b')
plt.ylabel('Medals')
plt.xticks(rotation=45)
plt.show()

# %%
year_avg_age = dataset.groupby('Year')['Age'].mean()
year_avg_age
# Out:
# Year
# 1896    23.580645
# 1900    28.881206
# 1904    26.698150
# 1906    27.125253
# 1908    26.995888
# 1912    27.538620
# 1920    29.290978
# 1924    28.027535
# 1928    27.855586
# 1932    29.586783
# 1936    26.952210
# 1948    28.386360
# 1952    26.161546
# 1956    25.926674
# 1960    25.168848
# 1964    24.944397
# 1968    24.248046
# 1972    24.308607
# 1976    23.841818
# 1980    23.694743
# 1984    23.898347
# 1988    24.079432
# 1992    24.318895
# 1994    24.422103
# 1996    24.915045
# 1998    25.163197
# 2000    25.422504
# 2002    25.916281
# 2004    25.639515
# 2006    25.959151
# 2008    25.734118
# 2010    26.124262
# 2012    25.961378
# 2014    25.987324
# 2016    26.207919
# Name: Age, dtype: float64

# %%
sport_median_height = dataset.groupby('Sport')['Height'].median().sort_values(ascending=True)
sport_median_height
# Out:
# Sport
# Gymnastics             164.0
# Diving                 167.0
# Trampolining           167.0
# Figure Skating         168.0
# Weightlifting          168.0
#                        ...
# Basque Pelota            NaN
# Cricket                  NaN
# Croquet                  NaN
# Military Ski Patrol      NaN
# Roque                    NaN
# Name: Height, Length: 66, dtype: float64

# %%
colors = cm.get_cmap('cool',len(sport_median_height))(np.arange(len(sport_median_height)))
ax = sport_median_height.plot(kind='bar',color=colors,figsize=(15,6))
ax.set_title("Required Height in Basis of Sport",fontsize = 20)
ax.set_xlabel("Sports",fontsize=15)
ax.set_ylabel("Heights",fontsize=15)
plt.show()

# %%
sport_median_height.min()
# Out:
# np.float64(164.0)

# %%
sport_median_height[sport_median_height == 164.0]
# Out:
# Sport
# Gymnastics    164.0
# Name: Height, dtype: float64

# %%
country_gender_count = dataset.groupby(['NOC','Sex'])['Sex'].count()
country_gender_count
# Out:
# NOC  Sex
# AFG  F         5
#      M       121
# AHO  F        12
#      M        67
# ALB  F        27
#             ...
# YUG  M      2201
# ZAM  F        19
#      M       164
# ZIM  F       113
#      M       198
# Name: Sex, Length: 452, dtype: int64

# %%
dataset['Medal'].value_counts()
# Out:
# Medal
# Gold      13369
# Bronze    13295
# Silver    13108
# Name: count, dtype: int64

# %%
country_gold_medals = dataset[dataset["Medal"] == "Gold"]
country_gold_medals.head()
# Out:
#     ID                     Name Sex   Age  Height  Weight            Team  \
# 3    4     Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 42  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 44  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 48  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 60  20       Kjetil Andr Aamodt   M  20.0   176.0    85.0          Norway
#
#     NOC        Games  Year  Season         City          Sport  \
# 3   DEN  1900 Summer  1900  Summer        Paris     Tug-Of-War
# 42  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 44  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 48  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 60  NOR  1992 Winter  1992  Winter  Albertville  Alpine Skiing
#
#                                Event Medal
# 3        Tug-Of-War Men's Tug-Of-War  Gold
# 42  Gymnastics Men's Team All-Around  Gold
# ...

# %%
country_gold_medals.groupby(['NOC'])['Medal'].count().sort_values(ascending=False)
# Out:
# NOC
# USA    2638
# URS    1082
# GER     745
# GBR     677
# ITA     575
#        ...
# SGP       1
# SYR       1
# TJK       1
# UAE       1
# VIE       1
# Name: Medal, Length: 109, dtype: int64

# %%
gold_medal = country_gold_medals.groupby(['NOC'])['Medal'].count().sort_values(ascending = False)

# %%
gold_medal = gold_medal.head(20)

# %%
gold_medal
# Out:
# NOC
# USA    2638
# URS    1082
# GER     745
# GBR     677
# ITA     575
# FRA     499
# SWE     479
# CAN     463
# HUN     432
# GDR     397
# RUS     390
# NOR     378
# CHN     350
# AUS     348
# NED     287
# JPN     247
# KOR     221
# FIN     198
# DEN     179
# SUI     175
# Name: Medal, dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm
colors = cm.get_cmap('plasma', len(gold_medal))(np.arange(len(gold_medal)))
ax = gold_medal.plot(kind='bar', color=colors, figsize=(15,6))
for container in ax.containers:
    ax.bar_label(container, label_type='edge', fontsize=10)
ax.set_title("Top 20 Highest Gold Medal Country")
ax.set_xlabel("Countries", fontsize=15)
ax.set_ylabel("Gold Medals", fontsize=15)
plt.xticks(rotation=40)
plt.show()

# %%
sport_gender_avg_weight = dataset.groupby(['Sport','Sex'])['Weight'].mean()
sport_gender_avg_weight
# Out:
# Sport          Sex
# Aeronautics    M            NaN
# Alpine Skiing  F      62.640307
#                M      78.626035
# Alpinism       F            NaN
#                M            NaN
#                         ...
# Water Polo     M      87.706172
# Weightlifting  F      67.724622
#                M      80.251796
# Wrestling      F      60.554455
#                M      76.400640
# Name: Weight, Length: 116, dtype: float64

# %%
sport_event_count = dataset.groupby('Sport')['Event'].nunique().sort_values(ascending=False)
sport_event_count
# Out:
# Sport
# Shooting      83
# Athletics     83
# Swimming      55
# Cycling       44
# Sailing       38
#               ..
# Polo           1
# Roque          1
# Rugby          1
# Softball       1
# Tug-Of-War     1
# Name: Event, Length: 66, dtype: int64

# %%
colors = cm.get_cmap('ocean',len(sport_event_count))(np.arange(len(sport_event_count)))
ax = sport_event_count.plot(kind='bar',color=colors,figsize=(15,6))
for i in ax.containers:
    ax.bar_label(i,fontsize=10)
ax.set_title('Number of Unique Events per Sport')
ax.set_xlabel('Sport',fontsize=15)
ax.set_ylabel('Number of Unique Events',fontsize=15)
plt.show()

# %%
year_participant_count = dataset.groupby(['Year'])['ID'].nunique()
year_participant_count.head()
# Out:
# Year
# 1896     176
# 1900    1224
# 1904     650
# 1906     841
# 1908    2024
# Name: ID, dtype: int64

# %%
colors = cm.get_cmap('brg',len(year_participant_count))(np.arange(len(year_participant_count)))
ax = year_participant_count.plot(kind='bar',color=colors,figsize=(15,6))
for i in ax.containers:
    ax.bar_label(i)
ax.set_title('Number of Participant Over the Year')
ax.set_xlabel('Year',fontsize=15)
ax.set_ylabel('Number of Paricipant',fontsize=15)
plt.show()

# %%
country_avg_age = dataset.groupby(['NOC'])['Age'].mean().sort_values(ascending=False)
country_avg_age
new =country_avg_age.head(10)

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(data=dataset,x='Height',y='Weight',hue='Medal')
plt.title("Athlete Height vs Weight by Medal Status")
plt.xlabel("Height")
plt.ylabel("Weight")
plt.legend()
plt.show()

# %%
colors = cm.get_cmap('cool',len(new))(np.arange(len(new)))
ax = new.plot(kind='bar',color=colors,figsize=(15,6))
for i in ax.containers:
    ax.bar_label(i)
ax.set_title('Top 10 Countries with Highest Average Age of Partcipant')
ax.set_xlabel('Countries',fontsize=15)
ax.set_ylabel('Average Age',fontsize=15)
plt.show()

# %%
dataset['Season'].value_counts()
# Out:
# Season
# Summer    221167
# Winter     48564
# Name: count, dtype: int64

# %%
sns.set(style='darkgrid')
sns.violinplot(data=dataset,x='Medal',y='Height',hue='Sex',palette='colorblind')
plt.title("Distribution of Height by Medal")
plt.xlabel("Medal")
plt.ylabel("Height")
plt.show()

# %%
sns.set(style='darkgrid')
sns.boxplot(data=dataset,x='Season',y='Age',hue='Sex',palette='colorblind')
plt.title("Distribution of Ages by Season")
plt.xlabel("Season")
plt.ylabel("Age")
plt.show()

# %%
most_medals_counrty = dataset['NOC'].value_counts().idxmax()
print("Most Medal-Winning Country:",most_medals_counrty)
# Out:
# Most Medal-Winning Country: USA

# %%
tallest_athlete = dataset[dataset['Height'] == dataset['Height'].max()]
print("Tallest Athlete:")
print(tallest_athlete[["ID","Name","Height","Sport"]])
# Out:
# Tallest Athlete:
#             ID      Name  Height       Sport
# 265040  132627  Yao Ming   226.0  Basketball
# 265041  132627  Yao Ming   226.0  Basketball
# 265042  132627  Yao Ming   226.0  Basketball

# %%
heaviest_athlete = dataset[dataset['Weight'] == dataset['Weight'].max()]
print("Heaviest Athlete:")
print(heaviest_athlete[["ID","Name","Height","Sport"]])
# Out:
# Heaviest Athlete:
#           ID               Name  Height Sport
# 23155  12177  Ricardo Blas, Jr.   183.0  Judo
# 23156  12177  Ricardo Blas, Jr.   183.0  Judo
